# %%
library(igraph)
# Out:
# Attaching package: 'igraph'
#
# The following objects are masked from 'package:stats':
#
#     decompose, spectrum
#
# The following object is masked from 'package:base':
#
#     union

# %%
g <- read.graph("data/actor_graph.txt",format="ncol",directed=T)
degree_dis <- degree_distribution(g)
plot(degree_dis, type="h", main="Degree distribution of actor/actress network", xlab="Degree", ylab="Frequency")
# Out:
# Plot with title "Degree distribution of actor/actress network"

# %%
degree_dis[1:300]
# Out:
#   [1] 0.000000e+00 0.000000e+00 1.769082e-05 0.000000e+00 5.218791e-04
#   [6] 0.000000e+00 2.653623e-05 0.000000e+00 7.164781e-04 0.000000e+00
#  [11] 7.076327e-05 0.000000e+00 6.987873e-04 0.000000e+00 1.061449e-04
#  [16] 0.000000e+00 7.341689e-04 0.000000e+00 1.680628e-04 0.000000e+00
#  [21] 6.987873e-04 0.000000e+00 1.680628e-04 0.000000e+00 7.253235e-04
#  [26] 0.000000e+00 1.415265e-04 0.000000e+00 4.068888e-04 0.000000e+00
#  [31] 3.095893e-04 0.000000e+00 7.783960e-04 0.000000e+00 1.857536e-04
#  [36] 0.000000e+00 8.049322e-04 0.000000e+00 2.211352e-04 0.000000e+00
#  [41] 1.034913e-03 0.000000e+00 3.715072e-04 0.000000e+00 8.049322e-04
#  [46] 0.000000e+00 3.538164e-04 0.000000e+00 1.202976e-03 0.000000e+00
#  [51] 4.157342e-04 0.000000e+00 9.995312e-04 0.000000e+00 3.715072e-04
#  [56] 0.000000e+00 8.845409e-04 0.000000e+00 5.218791e-04 0.000000e+00
#  [61] 1.141058e-03 0.000000e+00 3.803526e-04 0.000000e+00 8.580047e-04
# ...

# %%
max(degree_dis)
# Out:
# [1] 0.001954835

# %%
which.max(degree_dis)
# Out:
# [1] 377

# %%
which(V(g)$name == 113131)
# Out:
# [1] 109154

# %%
save(g,file='actor_graph_r.Rdata')

# %%
is_simple(g)
# Out:
# [1] FALSE
